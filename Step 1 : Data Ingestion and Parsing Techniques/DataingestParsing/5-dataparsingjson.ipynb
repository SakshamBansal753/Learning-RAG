# %% [markdown]
# # JSON Parsing

# %%
from typing import List, Tuple,Dict, Any
import os
import json

# %%
from langchain_community.document_loaders import JSONLoader
## Method 1: Load JSON file and parse it into a list of dictionaries
print("JSON Loader method")
employee_loadeer=JSONLoader(
    file_path="data/json_files/company_data.json",
    jq_schema=".employees[] ",
    text_content=False
)
employee_docs=employee_loadeer.load()
print(f"Number of employee documents loaded: {len(employee_docs)}")
print(f"First employee document: {employee_docs[0].page_content}")
print(f"First employee document metadata: {employee_docs[0].metadata}")
# Out:
# C:\Users\kanha\AppData\Local\Temp\ipykernel_16836\324603652.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import JSONLoader
# JSON Loader method
# Number of employee documents loaded: 2
# First employee document: {"id": 1, "name": "John Doe", "role": "Software Engineer", "skills": ["Python", "JavaScript", "React"], "projects": [{"name": "RAG System", "status": "In Progress"}, {"name": "Data Pipeline", "status": "Completed"}]}
# First employee document metadata: {'source': 'C:\\Users\\kanha\\OneDrive\\Documents\\RAG practice\\DataingestParsing\\data\\json_files\\company_data.json', 'seq_num': 1}

# %%
from langchain_core.documents import Document

# %%
## Method 2:Custom JSON parsing using Python's built-in json module
print("\nCustom JSON parsing method")
def process_json_intelligent(filepath:str)->List[Document]:
    with open(filepath, 'r') as file:
        data = json.load(file)
    
    documents = []
    for employee in data.get('employees', []):
        content = json.dumps(employee)  # Convert the employee dictionary to a JSON string
        metadata = {
            "name": employee.get("name"),
            "age": employee.get("age"),
            "department": employee.get("department")
        }
        documents.append(Document(page_content=content, metadata=metadata))
    
    return documents
# Out:
# Custom JSON parsing method

# %%
docs=process_json_intelligent("data/json_files/company_data.json")
print(f"Number of employee documents loaded: {len(docs)}")  
print(f"First employee document: {docs[0].page_content}")
print(f"First employee document metadata: {docs[0].metadata}")
# Out:
# Number of employee documents loaded: 2
# First employee document: {"id": 1, "name": "John Doe", "role": "Software Engineer", "skills": ["Python", "JavaScript", "React"], "projects": [{"name": "RAG System", "status": "In Progress"}, {"name": "Data Pipeline", "status": "Completed"}]}
# First employee document metadata: {'name': 'John Doe', 'age': None, 'department': None}
