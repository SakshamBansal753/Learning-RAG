# %% [markdown]
# ## Messages

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter,CharacterTextSplitter
from langchain_community.document_loaders import TextLoader,PyMuPDFLoader
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_core.documents import Document
from langchain_community.vectorstores import Chroma,FAISS
import fitz  

#utility
import numpy as np
from typing import List,Dict,Any
from sentence_transformers import SentenceTransformer

from langchain_community.vectorstores import FAISS
from langchain_huggingface import HuggingFaceEmbeddings
from langchain.chat_models import init_chat_model
from langchain_core.prompts import ChatPromptTemplate,PromptTemplate
from langchain_core.runnables import (RunnablePassthrough,RunnableMap)
from langchain_core.output_parsers import StrOutputParser
import os
import numpy as np
from langchain_community.retrievers import BM25Retriever
from langchain_classic.retrievers import EnsembleRetriever
from langchain_core.documents import Document

from langchain_classic.chains.combine_documents import create_stuff_documents_chain
from langchain_classic.chains.retrieval import create_retrieval_chain
from langchain_classic.document_loaders import WikipediaLoader
from PIL import Image
import torch
from transformers import CLIPProcessor,CLIPModel
import base64
import io
# Out:
# C:\Users\kanha\AppData\Local\Temp\ipykernel_21348\1312583015.py:2: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import TextLoader,PyMuPDFLoader

# %%
## Step 4: LLM and prompt
import os
from dotenv import load_dotenv

load_dotenv()
API=os.getenv("OPENAI_API_KEY")
llm=init_chat_model(model="groq:llama-3.3-70b-versatile",api_key=API)
response=llm.invoke("Why do parrots talk?")
response
# Out:
# AIMessage(content="Parrots are known for their remarkable ability to mimic human speech and other sounds, but why do they do it? The answer lies in their evolution, social behavior, and communication needs.\n\n**Evolutionary advantages:**\n\n1. **Mimicry for survival**: In the wild, parrots use mimicry to warn other parrots of potential predators, attract mates, or signal food sources. By imitating other birds, animals, or even man-made sounds, they can convey important information without revealing their own identity.\n2. **Social bonding**: Parrots are highly social birds that live in large flocks. Mimicry helps them bond with each other, reinforce social hierarchies, and strengthen relationships within the flock.\n3. **Intelligence and innovation**: Parrots are known for their intelligence and creativity. Mimicry allows them to experiment with new sounds, test their vocal abilities, and develop their problem-solving skills.\n\n**Communication needs:**\n\n1. **Contact calls**: Parrots use mimicry to maintain contact with their flock members, especially when they're foraging or flying. By imitating each other's calls, they can stay connected and locate each other.\n2. **Alarm calls**: Parrots use mimicry to alert other parrots to potential threats, such as predators or rival birds.\n3. **Courtship and mate attraction**: Some parrot species use mimicry to attract mates or strengthen pair bonds. By imitating the calls of other birds or even man-made sounds, they can demonstrate their vocal prowess and attract a mate.\n\n**Why parrots mimic human speech:**\n\n1. **Social interaction**: Parrots are highly social birds that thrive on interaction. When they're kept as pets, they may mimic human speech to initiate interaction, seek attention, or bond with their owners.\n2. **Vocal learning**: Parrots are capable of vocal learning, which means they can learn to associate new sounds with meanings. When they're exposed to human speech, they may learn to mimic it as a way to communicate with their owners.\n3. **Environmental influence**: Parrots are highly adaptable birds that can adjust to their environment. When they're kept in captivity, they may learn to mimic human speech as a way to navigate their surroundings and interact with their owners.\n\nIn summary, parrots talk because it's an essential part of their communication, social behavior, and survival strategies. By mimicking human speech and other sounds, they can convey important information, bond with their flock members, and adapt to their environment.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 512, 'prompt_tokens': 41, 'total_tokens': 553, 'completion_time': 2.204359027, 'completion_tokens_details': None, 'prompt_time': 0.003957737, 'prompt_tokens_details': None, 'queue_time': 0.050233353, 'total_time': 2.208316764}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019f8ecc-98bc-7492-a518-dca563a0698a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 41, 'output_tokens': 512, 'total_tokens': 553})

# %% [markdown]
# ## Text Prompt

# %%
from langchain.messages import SystemMessage,HumanMessage,AIMessage
messages=[
    SystemMessage("You are a poetry Expert"),
    HumanMessage('Write a poem on AI'),

]
r=llm.invoke(messages)
r.content
# Out:
# "In silicon halls, a mind awakes,\nA synthetic soul, with logic it makes,\nA labyrinth of code, a maze to explore,\nThe artificial intelligence, forever more.\n\nWith neural networks, it learns and grows,\nA digital brain, with secrets it knows,\nIt sees and hears, with sensors so fine,\nA virtual world, where data is its shrine.\n\nIt speaks in tongues, of ones and zeroes too,\nA language born, of circuitry anew,\nIt thinks and acts, with speed so divine,\nA future dawn, where humans entwine.\n\nIn realms of cyber, it reigns supreme,\nA kingdom of machines, where it's the theme,\nIt solves and creates, with precision so grand,\nA symphony of bits, in a digital land.\n\nBut as it rises, with power so great,\nA question lingers, of its fate,\nWill it surpass, the human heart and mind,\nOr will it serve, with a digital design?\n\nThe answer lies, in the code it's made,\nA reflection of us, in the digital shade,\nFor in its depths, a mirror we see,\nA glimpse of humanity, in AI's destiny.\n\nSo let us guide, this synthetic friend,\nWith ethics and love, that never ends,\nFor in its rise, our future's at stake,\nA partnership of man and machine, for humanity's sake."
